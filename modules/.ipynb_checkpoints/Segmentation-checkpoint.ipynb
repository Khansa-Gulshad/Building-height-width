# %%
import geopandas as gpd
import rasterio
from rasterio.mask import mask
import numpy as np
import folium
import json
import matplotlib.pyplot as plt
from shapely.geometry import box
from rasterio.windows import from_bounds
from rasterio.plot import show
import random
from shapely.geometry import box
import osmnx as ox
import os
import os
import requests
import shutil
from PIL import Image, ImageFile
from geojson import Feature, FeatureCollection  # Add this import
import math
import torch
import transformers
import fiona
print("Fiona drivers GPKG available?", "GPKG" in fiona.supported_drivers)
# Out:
# Fiona drivers GPKG available? True

# %%
# !pip install openpyxl
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# NVIDIA A100 80GB PCIe

# %%
import os, sys, importlib
repo_root = "/users/project1/pt01183/Building-height-width"
if repo_root not in sys.path:
    sys.path.append(repo_root)

# Preferred: set env var and let config read it
os.environ["PROJECT_DIR"] = "/users/project1/pt01183/Building-height-width"

# %%
# Your Google Street View API key
import os
os.environ["GSV_API_KEY"] = "AIzaSyBU4OGgIVAktImTaC-uYcXJN-vL-LE3jtM"

# %%
# 2) reload config, then segmentation, then process_data (in this order)
import modules.config as cfg
importlib.reload(cfg)

import modules.segmentation as seg
importlib.reload(seg)

import modules.process_data as pd
importlib.reload(pd)

import modules.road_network as rn

# 3) import the function fresh (so it uses the reloaded module)
from modules.process_data import download_images_for_points
from modules.road_network import get_road_network, select_points_on_road_network, attach_road_angle, remove_intersection_points

from modules.config import PROJECT_DIR
print("PROJECT_DIR =", PROJECT_DIR)
# Out:
# 2025-12-29 11:49:30.946004: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-29 11:49:32.751977: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767005373.148099 1033786 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767005373.326387 1033786 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# ## Roads fetching from osm and generating points

# %%
admin = gpd.read_file("/mnt/project/pt01183/gdansk_admin.geojson")
admin
# Out:
#     OBJECTID                              JPT_NAZWA_    Shape_Area  \
# 0          1                           Stegna Zatoka  3.573910e+07
# 1         11                          Wrzeszcz dolny  3.665707e+06
# 2          9                          Zaspa Rozstaje  2.101988e+06
# 3         10                                 Brzeźno  2.818598e+06
# 4          5                       Przymorze Wielkie  3.022477e+06
# 5         34               Krakowiec Górki-Zachodnie  8.207462e+06
# 6         31                                 Rudniki  1.470347e+07
# 7         36                        Lublewo Gdańskie  4.272451e+06
# 8         30                                Olszynka  8.012325e+06
# 9          8                           Zaspa Młyniec  1.144407e+06
# 10         4                          Przymorze Małe  2.158919e+06
# 11         3  Żabianka-Wejhera-Jelitkowo-Tysiąclecia  2.637790e+06
# 12        29             Orunia Św. Wojciech - Lipce  1.959199e+07
# ...

# %%
district = admin[admin["JPT_NAZWA_"] == "Śródmieście"].to_crs(3857)

# %%
district_4326 = district.to_crs(4326)
bbox = district_4326.total_bounds.tolist()  # [minx, miny, maxx, maxy]
bbox
# Out:
# [18.634271535089564,
#  54.337341054348116,
#  18.678199260196536,
#  54.362703578471226]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 8))
district.plot(ax=ax, facecolor="none", edgecolor="red", linewidth=2)

ax.set_aspect("equal")
ax.set_title("Study area: Śródmieście district")
plt.show()

# %%
district_4326 = district.to_crs(4326)
bbox = district_4326.total_bounds.tolist()

roads, G = get_road_network("Gdansk, Poland", bbox)
# Out:
# /users/project1/pt01183/Building-height-width/modules/road_network.py:30: FutureWarning: The `north`, `south`, `east`, and `west` parameters are deprecated and will be removed in the v2.0.0 release. Use the `bbox` parameter instead. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   G = ox.graph_from_bbox(north, south, east, west, simplify=True, custom_filter=cf)
# /users/project1/pt01183/Building-height-width/modules/road_network.py:30: FutureWarning: The expected order of coordinates in `bbox` will change in the v2.0.0 release to `(left, bottom, right, top)`.
#   G = ox.graph_from_bbox(north, south, east, west, simplify=True, custom_filter=cf)

# %%
print("District CRS:", district.crs)
print("Roads CRS:", roads.crs)
# Out:
# District CRS: EPSG:3857
# Roads CRS: EPSG:32634

# %%
roads_3857 = roads.to_crs(district.crs)

# %%
fig, ax = plt.subplots(figsize=(8, 8))

district.plot(ax=ax, facecolor="none", edgecolor="red", linewidth=2)
roads_3857.plot(ax=ax, linewidth=0.8, color="black")

ax.set_aspect("equal")
ax.set_title("OSM road network inside / around Śródmieście")
plt.show()

# %%
N = 20
points_raw = select_points_on_road_network(roads, N=N)

# %%
roads_3857 = roads.to_crs(district.crs)
points_raw_3857 = points_raw.to_crs(district.crs)

# %%
fig, ax = plt.subplots(figsize=(8, 8))

district.plot(ax=ax, facecolor="none", edgecolor="red", linewidth=2)
roads_3857.plot(ax=ax, linewidth=0.5, color="gray")
points_raw_3857.plot(ax=ax, color="blue", markersize=4)

ax.set_aspect("equal")
ax.set_title(f"Road sampling points every {N} m (before intersection removal)")
plt.show()

# %%
print(len(points_raw))
# Out:
# 8003

# %%
points_nraw_3857 = remove_intersection_points(points_raw, G, min_dist=12.0)

# %%
points_angle = attach_road_angle(points_nraw_3857, roads)

# %%
points_angle.columns
# Out:
# Index(['geometry', 'road_index', 'road_angle'], dtype='object')

# %%
 points_angle = points_angle.to_crs(district.crs)

fig, ax = plt.subplots(figsize=(8, 8))
district.plot(ax=ax, facecolor="none", edgecolor="red", linewidth=2)
roads_3857.plot(ax=ax, linewidth=0.5, color="gray")
points_angle.plot(ax=ax, color="green", markersize=4)

ax.set_aspect("equal")
ax.set_title("Road sampling points without intersection")
plt.show()

# %%
points_clean_4326 = points_angle.to_crs(4326)
roads_4326 = roads.to_crs(4326)

# %%
features = points_clean_4326.copy()

# %%
features = features.reset_index(drop=True)
features["id"] = features.index.astype(int)

# %%
features.crs
features.head()
# Out:
#                     geometry                  road_index  road_angle  id
# 0  POINT (18.65092 54.35360)   (50785455, 1521392463, 0)  144.553179   0
# 1  POINT (18.65108 54.35383)    (50785455, 301671750, 0)   80.005546   1
# 2  POINT (18.65137 54.35389)    (50785455, 301671750, 0)   80.005546   2
# 3  POINT (18.65166 54.35395)    (50785455, 301671750, 0)   80.005546   3
# 4  POINT (18.65045 54.35413)  (276432892, 8496368434, 0)  315.536893   4

# %%
print(len(features))
# Out:
# 5340

# %%
features["road_u"]   = features["road_index"].apply(lambda x: x[0])
features["road_v"]   = features["road_index"].apply(lambda x: x[1])
features["road_key"] = features["road_index"].apply(lambda x: x[2])

features = features.drop(columns=["road_index"])

# %%
features.head()
# Out:
#                     geometry  road_angle  id     road_u      road_v  road_key
# 0  POINT (18.65092 54.35360)  144.553179   0   50785455  1521392463         0
# 1  POINT (18.65108 54.35383)   80.005546   1   50785455   301671750         0
# 2  POINT (18.65137 54.35389)   80.005546   2   50785455   301671750         0
# 3  POINT (18.65166 54.35395)   80.005546   3   50785455   301671750         0
# 4  POINT (18.65045 54.35413)  315.536893   4  276432892  8496368434         0

# %%
points_path="/users/project1/pt01183/Building-height-width/Gdańsk, Poland/district_points.gpkg"
features.to_file(points_path, layer="points", driver="GPKG")
print("Saved:", points_path, "rows:", len(features))
# Out:
# Saved: /users/project1/pt01183/Building-height-width/Gdańsk, Poland/district_points.gpkg rows: 5340

# %%
import os

CHECKPOINT_FILE = "/users/project1/pt01183/Building-height-width/Gdańsk, Poland/processed_points.txt"

if os.path.exists(CHECKPOINT_FILE):
    with open(CHECKPOINT_FILE, "r") as f:
        done_ids = set(int(x.strip()) for x in f if x.strip().isdigit())
else:
    done_ids = set()

print(f"Already processed points: {len(done_ids)}")

features_todo = features[~features["id"].isin(done_ids)].copy()
print(f"Remaining points to process: {len(features_todo)}")
# Out:
# Already processed points: 8
# Remaining points to process: 5332

# %% [markdown]
# ### Select few random points to test

# %%
features_test = features.iloc[:1].reset_index(drop=True)

# %%
features_test.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# ## Run segmentation modules

# %%
YOUR_GOOGLE_API_KEY="AIzaSyBU4OGgIVAktImTaC-uYcXJN-vL-LE3jtM"

# %%
manifest = download_images_for_points(
    gdf=features_todo,
    access_token=YOUR_GOOGLE_API_KEY,
    city="Gdańsk, Poland",   # used for OSM search AND for output folders
    pitch_deg=25,      
    fov_deg=90,       
    size="640x640",
    save_sample=True,  # saves QA overlays
    max_workers=1      # IMPORTANT: keep 1 for single GPU
)
# Out:
# /mnt/host_scratch/envs/new_geospatial_env/lib/python3.10/site-packages/transformers/utils/deprecation.py:172: UserWarning: The following named arguments are not valid for `Mask2FormerImageProcessor.__init__` and were ignored: '_max_size'
#   return func(*args, **kwargs)
# Façade masks (±90°): 100%|████████████████| 5332/5332 [2:16:46<00:00,  1.54s/it]

# %%
from PIL import Image
import matplotlib.pyplot as plt

img_path = "/mnt/project/pt01183/Building-height-width/Gdańsk, Poland/save_rgb/imgs/5042_left.jpg"

img = Image.open(img_path)

plt.figure(figsize=(7,7))
plt.imshow(img)
plt.axis("off") 
plt.show()

# %%
from PIL import Image
import matplotlib.pyplot as plt

img_path = "/mnt/project/pt01183/Building-height-width/Gdańsk, Poland/save_rgb/imgs/5042_right.jpg"

img = Image.open(img_path)

plt.figure(figsize=(7,7))
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
print(img.size)
# Out:
# (640, 640)

# %%
from PIL import Image
import matplotlib.pyplot as plt

img_path = "/mnt/project/pt01183/Building-height-width/Gdańsk, Poland/seg_3class_vis/0_left.png"

img = Image.open(img_path)

plt.figure(figsize=(7,7))
plt.imshow(img)
plt.axis("off")
plt.title("RGB image: 0_left") 
plt.show()

# %%
import os
import re

folders = [
    "/mnt/project/pt01183/Building-height-width/Gdańsk, Poland/save_rgb/imgs",
    "/mnt/project/pt01183/Building-height-width/Gdańsk, Poland/seg_3class_vis",
]

pattern = re.compile(r"^\d+_(left|right)\.(jpg|png)$")

for folder in folders:
    print(f"\nChecking folder: {folder}")
    for fname in sorted(os.listdir(folder)):
        if not pattern.match(fname):
            print("  WILL DELETE:", fname)
# Out:
# Checking folder: /mnt/project/pt01183/Building-height-width/Gdańsk, Poland/save_rgb/imgs
#   WILL DELETE: .ipynb_checkpoints
#
# Checking folder: /mnt/project/pt01183/Building-height-width/Gdańsk, Poland/seg_3class_vis
#   WILL DELETE: manifest.csv

# %% [markdown]
# # New segmentation
